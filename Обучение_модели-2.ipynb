# %%
# !pip install facenet-pytorch

# %%
import pandas as pd
import shutil
import os
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.autograd import Variable
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import sys
import os
import time
import torch.nn.functional as F
import os
import random
from torch.optim.lr_scheduler import ReduceLROnPlateau
from facenet_pytorch import InceptionResnetV1, fixed_image_standardization, training

# %%
data_transforms = transforms.Compose([
        np.float32,
        transforms.ToTensor(),
        fixed_image_standardization
])

image_dataset = datasets.ImageFolder('faces',  data_transforms)

# %%
os.listdir('faces')
# Out:
# ['Neymar_Jr_football',
#  'Sergio_Ramos_football',
#  'L._Messi_football',
#  'R._Lewandowski_football',
#  'L._Suárez_football',
#  'M._Neuer_football',
#  'E._Hazard_football',
#  'H._Kane_football',
#  'T._Kroos_football']

# %%
os.listdir('faces.')

# %%
if os.path.exists('faces/.DS_Store'):
    os.remove(os.path.join('faces', '.DS_Store' ))

if os.path.exists('faces/.ipynb_checkpoints'):
    os.remove(os.path.join('faces', '.ipynb_checkpoints' ))

# %%
img_inds = np.arange(len(image_dataset))

# %%
np.random.shuffle(img_inds)

# %%
train_inds = img_inds[:int(0.8 * len(img_inds))]
val_inds = img_inds[int(0.8 * len(img_inds)):]

# %%
from torch.utils.data import DataLoader, SubsetRandomSampler
from facenet_pytorch import InceptionResnetV1

# %%
train_loader = DataLoader(
    image_dataset,
    num_workers=2,
    batch_size=20,
    sampler=SubsetRandomSampler(train_inds),
    drop_last=True
)
val_loader = DataLoader(
    image_dataset,
    num_workers=2,
    batch_size=20,
    sampler=SubsetRandomSampler(val_inds),
    drop_last=True
)

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
loss_fn = torch.nn.CrossEntropyLoss()
metrics = {
    'acc': training.accuracy
}

# %%
 def complete_epoch(model, loss_fn, loader, optimizer=None, scheduler=None,  batch_metrics=metrics, device=device):   
    mode = 'Train' if model.training else 'Valid'
    print(mode)
    loss = 0
    metrics = {}
    for i_batch, (x, y) in enumerate(loader):
        x = x.to(device)
        y = y.to(device)
        y_pred = model(x)

        loss_batch = loss_fn(y_pred, y)
        

        if model.training:
            loss_batch.backward()
            optimizer.step()
            optimizer.zero_grad()


        
        metrics_batch = {}
        for metric_name, metric_fn in batch_metrics.items():
            metrics_batch[metric_name] = metric_fn(y_pred, y).detach().cpu()
            metrics[metric_name] = metrics.get(metric_name, 0) + metrics_batch[metric_name]
            

        loss_batch = loss_batch.detach().cpu()
        loss += loss_batch

    loss = loss / (i_batch + 1)
    metrics = {k: v / (i_batch + 1) for k, v in metrics.items()}

    return loss, metrics

# %%
len(image_dataset.class_to_idx)
# Out:
# 9

# %%
image_dataset.class_to_idx
# Out:
# {'E._Hazard_football': 0,
#  'H._Kane_football': 1,
#  'L._Messi_football': 2,
#  'L._Suárez_football': 3,
#  'M._Neuer_football': 4,
#  'Neymar_Jr_football': 5,
#  'R._Lewandowski_football': 6,
#  'Sergio_Ramos_football': 7,
#  'T._Kroos_football': 8}

# %%
from facenet_pytorch import InceptionResnetV1

resnet = InceptionResnetV1(
    classify=True,
    num_classes=len(image_dataset.class_to_idx)
).to(device)

optimizer = optim.Adam(resnet.parameters(), lr=0.001)

# %%
import pickle
file_save = open("ids_to_player.pkl", "wb")
pickle.dump(image_dataset.class_to_idx, file_save)
file_save.close()

# %%
dic = {value:key for key, value in output.items()}

# %%
a_file = open("ids_to_player.pkl", "wb")
pickle.dump(dic, a_file)
a_file.close()

# %%
for p in resnet.named_parameters():
    p[1].requires_grad = False

# %%
resnet.logits.weight.requires_grad = True
resnet.logits.bias.requires_grad = True

# %%
loss_fn = torch.nn.CrossEntropyLoss()
metrics = {
    'acc': training.accuracy
}

# %%
best_loss = np.inf
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.5)
no_improvement = 0
for epoch in range(40):
    resnet.train()
    p_count = 0
    for p in resnet.named_parameters():
        if p_count >= len(list(resnet.named_parameters()))-2-3*epoch:
            p[1].requires_grad = True
    p_count += 1
    complete_epoch(resnet, loss_fn, train_loader, optimizer=optimizer, scheduler=None,  batch_metrics=metrics, device=device)
    resnet.eval()
    val_loss, acc =  complete_epoch(resnet, loss_fn, val_loader, optimizer=optimizer, scheduler=None,  batch_metrics=metrics, device=device)
    print(val_loss)
    print(best_loss)
    print(acc)
    if val_loss < best_loss:
        no_improvement = 0
        best_loss = val_loss
        print('hello')
        torch.save({
            'model_state_dict': resnet.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            }, '/content/gdrive/MyDrive/resnet_model_best_weights/model_best.pt'.format(str(epoch)))
    else:
        scheduler
        no_improvement += 1
        scheduler.step()
        if no_improvement == 5:
            print('No Improvement for 5 epochs, Early Stopping')
            break
# Out:
# Tracking Gradient For: logits.weight
# Tracking Gradient For: logits.bias
# Train
# Valid
# tensor(0.4383)
# inf
# {'acc': tensor(0.9211)}
# hello
# Tracking Gradient For: last_linear.weight
# Tracking Gradient For: last_bn.weight
# Tracking Gradient For: last_bn.bias
# Tracking Gradient For: logits.weight
# Tracking Gradient For: logits.bias
# Train
# Valid
# tensor(0.2722)
# tensor(0.4383)
# {'acc': tensor(0.9211)}
# hello
# Tracking Gradient For: block8.branch1.2.bn.bias
# Tracking Gradient For: block8.conv2d.weight
# Tracking Gradient For: block8.conv2d.bias
# Tracking Gradient For: last_linear.weight
# Tracking Gradient For: last_bn.weight
# Tracking Gradient For: last_bn.bias
# Tracking Gradient For: logits.weight
# Tracking Gradient For: logits.bias
# Train
# Valid
# tensor(0.2764)
# tensor(0.2722)
# {'acc': tensor(0.9342)}
# Tracking Gradient For: block8.branch1.1.bn.bias
# Tracking Gradient For: block8.branch1.2.conv.weight
# Tracking Gradient For: block8.branch1.2.bn.weight
# Tracking Gradient For: block8.branch1.2.bn.bias
# Tracking Gradient For: block8.conv2d.weight
# Tracking Gradient For: block8.conv2d.bias
# Tracking Gradient For: last_linear.weight
# Tracking Gradient For: last_bn.weight
# Tracking Gradient For: last_bn.bias
# Tracking Gradient For: logits.weight
# Tracking Gradient For: logits.bias
# Train
# Valid
# tensor(0.2477)
# tensor(0.2722)
# {'acc': tensor(0.9237)}
# hello
# Tracking Gradient For: block8.branch1.0.bn.bias
# Tracking Gradient For: block8.branch1.1.conv.weight
# Tracking Gradient For: block8.branch1.1.bn.weight
# Tracking Gradient For: block8.branch1.1.bn.bias
# Tracking Gradient For: block8.branch1.2.conv.weight
# Tracking Gradient For: block8.branch1.2.bn.weight
# Tracking Gradient For: block8.branch1.2.bn.bias
# Tracking Gradient For: block8.conv2d.weight
# Tracking Gradient For: block8.conv2d.bias
# Tracking Gradient For: last_linear.weight
# Tracking Gradient For: last_bn.weight
# Tracking Gradient For: last_bn.bias
# Tracking Gradient For: logits.weight
# Tracking Gradient For: logits.bias
# Train
# Valid
# tensor(0.2035)
# tensor(0.2477)
# {'acc': tensor(0.9447)}
# hello
# Tracking Gradient For: block8.branch0.bn.bias
# Tracking Gradient For: block8.branch1.0.conv.weight
# Tracking Gradient For: block8.branch1.0.bn.weight
# Tracking Gradient For: block8.branch1.0.bn.bias
# Tracking Gradient For: block8.branch1.1.conv.weight
# Tracking Gradient For: block8.branch1.1.bn.weight
# Tracking Gradient For: block8.branch1.1.bn.bias
# Tracking Gradient For: block8.branch1.2.conv.weight
# Tracking Gradient For: block8.branch1.2.bn.weight
# Tracking Gradient For: block8.branch1.2.bn.bias
# Tracking Gradient For: block8.conv2d.weight
# Tracking Gradient For: block8.conv2d.bias
# Tracking Gradient For: last_linear.weight
# Tracking Gradient For: last_bn.weight
# Tracking Gradient For: last_bn.bias
# Tracking Gradient For: logits.weight
# Tracking Gradient For: logits.bias
# Train
# Valid
# tensor(0.2176)
# tensor(0.2035)
# {'acc': tensor(0.9421)}
# Tracking Gradient For: repeat_3.4.conv2d.bias
# Tracking Gradient For: block8.branch0.conv.weight
# Tracking Gradient For: block8.branch0.bn.weight
# Tracking Gradient For: block8.branch0.bn.bias
# Tracking Gradient For: block8.branch1.0.conv.weight
# Tracking Gradient For: block8.branch1.0.bn.weight
# Tracking Gradient For: block8.branch1.0.bn.bias
# Tracking Gradient For: block8.branch1.1.conv.weight
# Tracking Gradient For: block8.branch1.1.bn.weight
# Tracking Gradient For: block8.branch1.1.bn.bias
# Tracking Gradient For: block8.branch1.2.conv.weight
# Tracking Gradient For: block8.branch1.2.bn.weight
# Tracking Gradient For: block8.branch1.2.bn.bias
# Tracking Gradient For: block8.conv2d.weight
# Tracking Gradient For: block8.conv2d.bias
# Tracking Gradient For: last_linear.weight
# Tracking Gradient For: last_bn.weight
# Tracking Gradient For: last_bn.bias
# Tracking Gradient For: logits.weight
# Tracking Gradient For: logits.bias
# Train
# Valid
# tensor(0.2053)
# tensor(0.2035)
# {'acc': tensor(0.9500)}
# Tracking Gradient For: repeat_3.4.branch1.2.bn.weight
# Tracking Gradient For: repeat_3.4.branch1.2.bn.bias
# Tracking Gradient For: repeat_3.4.conv2d.weight
# Tracking Gradient For: repeat_3.4.conv2d.bias
# Tracking Gradient For: block8.branch0.conv.weight
# Tracking Gradient For: block8.branch0.bn.weight
# Tracking Gradient For: block8.branch0.bn.bias
# Tracking Gradient For: block8.branch1.0.conv.weight
# Tracking Gradient For: block8.branch1.0.bn.weight
# Tracking Gradient For: block8.branch1.0.bn.bias
# Tracking Gradient For: block8.branch1.1.conv.weight
# Tracking Gradient For: block8.branch1.1.bn.weight
# Tracking Gradient For: block8.branch1.1.bn.bias
# Tracking Gradient For: block8.branch1.2.conv.weight
# Tracking Gradient For: block8.branch1.2.bn.weight
# Tracking Gradient For: block8.branch1.2.bn.bias
# Tracking Gradient For: block8.conv2d.weight
# Tracking Gradient For: block8.conv2d.bias
# Tracking Gradient For: last_linear.weight
# Tracking Gradient For: last_bn.weight
# Tracking Gradient For: last_bn.bias
# Tracking Gradient For: logits.weight
# Tracking Gradient For: logits.bias
# Train
# Valid
# tensor(0.1805)
# tensor(0.2035)
# {'acc': tensor(0.9500)}
# hello
# Tracking Gradient For: repeat_3.4.branch1.1.bn.weight
# Tracking Gradient For: repeat_3.4.branch1.1.bn.bias
# Tracking Gradient For: repeat_3.4.branch1.2.conv.weight
# Tracking Gradient For: repeat_3.4.branch1.2.bn.weight
# Tracking Gradient For: repeat_3.4.branch1.2.bn.bias
# Tracking Gradient For: repeat_3.4.conv2d.weight
# Tracking Gradient For: repeat_3.4.conv2d.bias
# Tracking Gradient For: block8.branch0.conv.weight
# Tracking Gradient For: block8.branch0.bn.weight
# Tracking Gradient For: block8.branch0.bn.bias
# Tracking Gradient For: block8.branch1.0.conv.weight
# Tracking Gradient For: block8.branch1.0.bn.weight
# Tracking Gradient For: block8.branch1.0.bn.bias
# Tracking Gradient For: block8.branch1.1.conv.weight
# Tracking Gradient For: block8.branch1.1.bn.weight
# Tracking Gradient For: block8.branch1.1.bn.bias
# Tracking Gradient For: block8.branch1.2.conv.weight
# Tracking Gradient For: block8.branch1.2.bn.weight
# Tracking Gradient For: block8.branch1.2.bn.bias
# Tracking Gradient For: block8.conv2d.weight
# Tracking Gradient For: block8.conv2d.bias
# Tracking Gradient For: last_linear.weight
# Tracking Gradient For: last_bn.weight
# Tracking Gradient For: last_bn.bias
# Tracking Gradient For: logits.weight
# Tracking Gradient For: logits.bias
# Train
# Valid
# tensor(0.1752)
# tensor(0.1805)
# {'acc': tensor(0.9500)}
# hello
# Tracking Gradient For: repeat_3.4.branch1.0.bn.weight
# Tracking Gradient For: repeat_3.4.branch1.0.bn.bias
# Tracking Gradient For: repeat_3.4.branch1.1.conv.weight
# Tracking Gradient For: repeat_3.4.branch1.1.bn.weight
# Tracking Gradient For: repeat_3.4.branch1.1.bn.bias
# Tracking Gradient For: repeat_3.4.branch1.2.conv.weight
# Tracking Gradient For: repeat_3.4.branch1.2.bn.weight
# Tracking Gradient For: repeat_3.4.branch1.2.bn.bias
# Tracking Gradient For: repeat_3.4.conv2d.weight
# Tracking Gradient For: repeat_3.4.conv2d.bias
# Tracking Gradient For: block8.branch0.conv.weight
# Tracking Gradient For: block8.branch0.bn.weight
# Tracking Gradient For: block8.branch0.bn.bias
# Tracking Gradient For: block8.branch1.0.conv.weight
# Tracking Gradient For: block8.branch1.0.bn.weight
# Tracking Gradient For: block8.branch1.0.bn.bias
# Tracking Gradient For: block8.branch1.1.conv.weight
# Tracking Gradient For: block8.branch1.1.bn.weight
# Tracking Gradient For: block8.branch1.1.bn.bias
# Tracking Gradient For: block8.branch1.2.conv.weight
# Tracking Gradient For: block8.branch1.2.bn.weight
# Tracking Gradient For: block8.branch1.2.bn.bias
# Tracking Gradient For: block8.conv2d.weight
# Tracking Gradient For: block8.conv2d.bias
# Tracking Gradient For: last_linear.weight
# Tracking Gradient For: last_bn.weight
# Tracking Gradient For: last_bn.bias
# Tracking Gradient For: logits.weight
# Tracking Gradient For: logits.bias
# Train
# Valid
# tensor(0.1669)
# tensor(0.1752)
# {'acc': tensor(0.9500)}
# hello
# Tracking Gradient For: repeat_3.4.branch0.bn.weight
# Tracking Gradient For: repeat_3.4.branch0.bn.bias
# Tracking Gradient For: repeat_3.4.branch1.0.conv.weight
# Tracking Gradient For: repeat_3.4.branch1.0.bn.weight
# Tracking Gradient For: repeat_3.4.branch1.0.bn.bias
# Tracking Gradient For: repeat_3.4.branch1.1.conv.weight
# Tracking Gradient For: repeat_3.4.branch1.1.bn.weight
# Tracking Gradient For: repeat_3.4.branch1.1.bn.bias
# Tracking Gradient For: repeat_3.4.branch1.2.conv.weight
# Tracking Gradient For: repeat_3.4.branch1.2.bn.weight
# Tracking Gradient For: repeat_3.4.branch1.2.bn.bias
# Tracking Gradient For: repeat_3.4.conv2d.weight
# Tracking Gradient For: repeat_3.4.conv2d.bias
# Tracking Gradient For: block8.branch0.conv.weight
# Tracking Gradient For: block8.branch0.bn.weight
# Tracking Gradient For: block8.branch0.bn.bias
# Tracking Gradient For: block8.branch1.0.conv.weight
# Tracking Gradient For: block8.branch1.0.bn.weight
# Tracking Gradient For: block8.branch1.0.bn.bias
# Tracking Gradient For: block8.branch1.1.conv.weight
# Tracking Gradient For: block8.branch1.1.bn.weight
# Tracking Gradient For: block8.branch1.1.bn.bias
# Tracking Gradient For: block8.branch1.2.conv.weight
# Tracking Gradient For: block8.branch1.2.bn.weight
# Tracking Gradient For: block8.branch1.2.bn.bias
# Tracking Gradient For: block8.conv2d.weight
# Tracking Gradient For: block8.conv2d.bias
# Tracking Gradient For: last_linear.weight
# Tracking Gradient For: last_bn.weight
# Tracking Gradient For: last_bn.bias
# Tracking Gradient For: logits.weight
# Tracking Gradient For: logits.bias
# Train
# Valid
# tensor(0.1619)
# tensor(0.1669)
# {'acc': tensor(0.9605)}
# hello
# Tracking Gradient For: repeat_3.3.conv2d.weight
# Tracking Gradient For: repeat_3.3.conv2d.bias
# Tracking Gradient For: repeat_3.4.branch0.conv.weight
# Tracking Gradient For: repeat_3.4.branch0.bn.weight
# Tracking Gradient For: repeat_3.4.branch0.bn.bias
# Tracking Gradient For: repeat_3.4.branch1.0.conv.weight
# Tracking Gradient For: repeat_3.4.branch1.0.bn.weight
# Tracking Gradient For: repeat_3.4.branch1.0.bn.bias
# Tracking Gradient For: repeat_3.4.branch1.1.conv.weight
# Tracking Gradient For: repeat_3.4.branch1.1.bn.weight
# Tracking Gradient For: repeat_3.4.branch1.1.bn.bias
# Tracking Gradient For: repeat_3.4.branch1.2.conv.weight
# Tracking Gradient For: repeat_3.4.branch1.2.bn.weight
# Tracking Gradient For: repeat_3.4.branch1.2.bn.bias
# Tracking Gradient For: repeat_3.4.conv2d.weight
# Tracking Gradient For: repeat_3.4.conv2d.bias
# Tracking Gradient For: block8.branch0.conv.weight
# Tracking Gradient For: block8.branch0.bn.weight
# Tracking Gradient For: block8.branch0.bn.bias
# Tracking Gradient For: block8.branch1.0.conv.weight
# Tracking Gradient For: block8.branch1.0.bn.weight
# Tracking Gradient For: block8.branch1.0.bn.bias
# Tracking Gradient For: block8.branch1.1.conv.weight
# Tracking Gradient For: block8.branch1.1.bn.weight
# Tracking Gradient For: block8.branch1.1.bn.bias
# Tracking Gradient For: block8.branch1.2.conv.weight
# Tracking Gradient For: block8.branch1.2.bn.weight
# Tracking Gradient For: block8.branch1.2.bn.bias
# Tracking Gradient For: block8.conv2d.weight
# Tracking Gradient For: block8.conv2d.bias
# Tracking Gradient For: last_linear.weight
# Tracking Gradient For: last_bn.weight
# Tracking Gradient For: last_bn.bias
# Tracking Gradient For: logits.weight
# Tracking Gradient For: logits.bias
# Train
# Valid
# tensor(0.1776)
# tensor(0.1619)
# {'acc': tensor(0.9500)}
# Tracking Gradient For: repeat_3.3.branch1.2.conv.weight
# Tracking Gradient For: repeat_3.3.branch1.2.bn.weight
# Tracking Gradient For: repeat_3.3.branch1.2.bn.bias
# Tracking Gradient For: repeat_3.3.conv2d.weight
# Tracking Gradient For: repeat_3.3.conv2d.bias
# Tracking Gradient For: repeat_3.4.branch0.conv.weight
# Tracking Gradient For: repeat_3.4.branch0.bn.weight
# Tracking Gradient For: repeat_3.4.branch0.bn.bias
# Tracking Gradient For: repeat_3.4.branch1.0.conv.weight
# Tracking Gradient For: repeat_3.4.branch1.0.bn.weight
# Tracking Gradient For: repeat_3.4.branch1.0.bn.bias
# Tracking Gradient For: repeat_3.4.branch1.1.conv.weight
# Tracking Gradient For: repeat_3.4.branch1.1.bn.weight
# Tracking Gradient For: repeat_3.4.branch1.1.bn.bias
# Tracking Gradient For: repeat_3.4.branch1.2.conv.weight
# Tracking Gradient For: repeat_3.4.branch1.2.bn.weight
# Tracking Gradient For: repeat_3.4.branch1.2.bn.bias
# Tracking Gradient For: repeat_3.4.conv2d.weight
# Tracking Gradient For: repeat_3.4.conv2d.bias
# Tracking Gradient For: block8.branch0.conv.weight
# Tracking Gradient For: block8.branch0.bn.weight
# Tracking Gradient For: block8.branch0.bn.bias
# Tracking Gradient For: block8.branch1.0.conv.weight
# Tracking Gradient For: block8.branch1.0.bn.weight
# Tracking Gradient For: block8.branch1.0.bn.bias
# Tracking Gradient For: block8.branch1.1.conv.weight
# Tracking Gradient For: block8.branch1.1.bn.weight
# Tracking Gradient For: block8.branch1.1.bn.bias
# Tracking Gradient For: block8.branch1.2.conv.weight
# Tracking Gradient For: block8.branch1.2.bn.weight
# Tracking Gradient For: block8.branch1.2.bn.bias
# Tracking Gradient For: block8.conv2d.weight
# Tracking Gradient For: block8.conv2d.bias
# Tracking Gradient For: last_linear.weight
# Tracking Gradient For: last_bn.weight
# Tracking Gradient For: last_bn.bias
# Tracking Gradient For: logits.weight
# Tracking Gradient For: logits.bias
# Train
# Valid
# tensor(0.1794)
# tensor(0.1619)
# {'acc': tensor(0.9500)}
# Tracking Gradient For: repeat_3.3.branch1.1.conv.weight
# Tracking Gradient For: repeat_3.3.branch1.1.bn.weight
# Tracking Gradient For: repeat_3.3.branch1.1.bn.bias
# Tracking Gradient For: repeat_3.3.branch1.2.conv.weight
# Tracking Gradient For: repeat_3.3.branch1.2.bn.weight
# Tracking Gradient For: repeat_3.3.branch1.2.bn.bias
# Tracking Gradient For: repeat_3.3.conv2d.weight
# Tracking Gradient For: repeat_3.3.conv2d.bias
# Tracking Gradient For: repeat_3.4.branch0.conv.weight
# Tracking Gradient For: repeat_3.4.branch0.bn.weight
# Tracking Gradient For: repeat_3.4.branch0.bn.bias
# Tracking Gradient For: repeat_3.4.branch1.0.conv.weight
# Tracking Gradient For: repeat_3.4.branch1.0.bn.weight
# Tracking Gradient For: repeat_3.4.branch1.0.bn.bias
# Tracking Gradient For: repeat_3.4.branch1.1.conv.weight
# Tracking Gradient For: repeat_3.4.branch1.1.bn.weight
# Tracking Gradient For: repeat_3.4.branch1.1.bn.bias
# Tracking Gradient For: repeat_3.4.branch1.2.conv.weight
# Tracking Gradient For: repeat_3.4.branch1.2.bn.weight
# Tracking Gradient For: repeat_3.4.branch1.2.bn.bias
# Tracking Gradient For: repeat_3.4.conv2d.weight
# Tracking Gradient For: repeat_3.4.conv2d.bias
# Tracking Gradient For: block8.branch0.conv.weight
# Tracking Gradient For: block8.branch0.bn.weight
# Tracking Gradient For: block8.branch0.bn.bias
# Tracking Gradient For: block8.branch1.0.conv.weight
# Tracking Gradient For: block8.branch1.0.bn.weight
# Tracking Gradient For: block8.branch1.0.bn.bias
# Tracking Gradient For: block8.branch1.1.conv.weight
# Tracking Gradient For: block8.branch1.1.bn.weight
# Tracking Gradient For: block8.branch1.1.bn.bias
# Tracking Gradient For: block8.branch1.2.conv.weight
# Tracking Gradient For: block8.branch1.2.bn.weight
# Tracking Gradient For: block8.branch1.2.bn.bias
# Tracking Gradient For: block8.conv2d.weight
# Tracking Gradient For: block8.conv2d.bias
# Tracking Gradient For: last_linear.weight
# Tracking Gradient For: last_bn.weight
# Tracking Gradient For: last_bn.bias
# Tracking Gradient For: logits.weight
# Tracking Gradient For: logits.bias
# Train
# Valid
# tensor(0.1577)
# tensor(0.1619)
# {'acc': tensor(0.9605)}
# hello
# Tracking Gradient For: repeat_3.3.branch1.0.conv.weight
# Tracking Gradient For: repeat_3.3.branch1.0.bn.weight
# Tracking Gradient For: repeat_3.3.branch1.0.bn.bias
# Tracking Gradient For: repeat_3.3.branch1.1.conv.weight
# Tracking Gradient For: repeat_3.3.branch1.1.bn.weight
# Tracking Gradient For: repeat_3.3.branch1.1.bn.bias
# Tracking Gradient For: repeat_3.3.branch1.2.conv.weight
# Tracking Gradient For: repeat_3.3.branch1.2.bn.weight
# Tracking Gradient For: repeat_3.3.branch1.2.bn.bias
# Tracking Gradient For: repeat_3.3.conv2d.weight
# Tracking Gradient For: repeat_3.3.conv2d.bias
# Tracking Gradient For: repeat_3.4.branch0.conv.weight
# Tracking Gradient For: repeat_3.4.branch0.bn.weight
# Tracking Gradient For: repeat_3.4.branch0.bn.bias
# Tracking Gradient For: repeat_3.4.branch1.0.conv.weight
# Tracking Gradient For: repeat_3.4.branch1.0.bn.weight
# Tracking Gradient For: repeat_3.4.branch1.0.bn.bias
# Tracking Gradient For: repeat_3.4.branch1.1.conv.weight
# Tracking Gradient For: repeat_3.4.branch1.1.bn.weight
# Tracking Gradient For: repeat_3.4.branch1.1.bn.bias
# Tracking Gradient For: repeat_3.4.branch1.2.conv.weight
# Tracking Gradient For: repeat_3.4.branch1.2.bn.weight
# Tracking Gradient For: repeat_3.4.branch1.2.bn.bias
# Tracking Gradient For: repeat_3.4.conv2d.weight
# Tracking Gradient For: repeat_3.4.conv2d.bias
# Tracking Gradient For: block8.branch0.conv.weight
# Tracking Gradient For: block8.branch0.bn.weight
# Tracking Gradient For: block8.branch0.bn.bias
# Tracking Gradient For: block8.branch1.0.conv.weight
# Tracking Gradient For: block8.branch1.0.bn.weight
# Tracking Gradient For: block8.branch1.0.bn.bias
# Tracking Gradient For: block8.branch1.1.conv.weight
# Tracking Gradient For: block8.branch1.1.bn.weight
# Tracking Gradient For: block8.branch1.1.bn.bias
# Tracking Gradient For: block8.branch1.2.conv.weight
# Tracking Gradient For: block8.branch1.2.bn.weight
# Tracking Gradient For: block8.branch1.2.bn.bias
# Tracking Gradient For: block8.conv2d.weight
# Tracking Gradient For: block8.conv2d.bias
# Tracking Gradient For: last_linear.weight
# Tracking Gradient For: last_bn.weight
# Tracking Gradient For: last_bn.bias
# Tracking Gradient For: logits.weight
# Tracking Gradient For: logits.bias
# Train
# Valid
# tensor(0.1772)
# tensor(0.1577)
# {'acc': tensor(0.9553)}
# Tracking Gradient For: repeat_3.3.branch0.conv.weight
# Tracking Gradient For: repeat_3.3.branch0.bn.weight
# Tracking Gradient For: repeat_3.3.branch0.bn.bias
# Tracking Gradient For: repeat_3.3.branch1.0.conv.weight
# Tracking Gradient For: repeat_3.3.branch1.0.bn.weight
# Tracking Gradient For: repeat_3.3.branch1.0.bn.bias
# Tracking Gradient For: repeat_3.3.branch1.1.conv.weight
# Tracking Gradient For: repeat_3.3.branch1.1.bn.weight
# Tracking Gradient For: repeat_3.3.branch1.1.bn.bias
# Tracking Gradient For: repeat_3.3.branch1.2.conv.weight
# Tracking Gradient For: repeat_3.3.branch1.2.bn.weight
# Tracking Gradient For: repeat_3.3.branch1.2.bn.bias
# Tracking Gradient For: repeat_3.3.conv2d.weight
# Tracking Gradient For: repeat_3.3.conv2d.bias
# Tracking Gradient For: repeat_3.4.branch0.conv.weight
# Tracking Gradient For: repeat_3.4.branch0.bn.weight
# Tracking Gradient For: repeat_3.4.branch0.bn.bias
# Tracking Gradient For: repeat_3.4.branch1.0.conv.weight
# Tracking Gradient For: repeat_3.4.branch1.0.bn.weight
# Tracking Gradient For: repeat_3.4.branch1.0.bn.bias
# Tracking Gradient For: repeat_3.4.branch1.1.conv.weight
# Tracking Gradient For: repeat_3.4.branch1.1.bn.weight
# Tracking Gradient For: repeat_3.4.branch1.1.bn.bias
# Tracking Gradient For: repeat_3.4.branch1.2.conv.weight
# Tracking Gradient For: repeat_3.4.branch1.2.bn.weight
# Tracking Gradient For: repeat_3.4.branch1.2.bn.bias
# Tracking Gradient For: repeat_3.4.conv2d.weight
# Tracking Gradient For: repeat_3.4.conv2d.bias
# Tracking Gradient For: block8.branch0.conv.weight
# Tracking Gradient For: block8.branch0.bn.weight
# Tracking Gradient For: block8.branch0.bn.bias
# Tracking Gradient For: block8.branch1.0.conv.weight
# Tracking Gradient For: block8.branch1.0.bn.weight
# Tracking Gradient For: block8.branch1.0.bn.bias
# Tracking Gradient For: block8.branch1.1.conv.weight
# Tracking Gradient For: block8.branch1.1.bn.weight
# Tracking Gradient For: block8.branch1.1.bn.bias
# Tracking Gradient For: block8.branch1.2.conv.weight
# Tracking Gradient For: block8.branch1.2.bn.weight
# Tracking Gradient For: block8.branch1.2.bn.bias
# Tracking Gradient For: block8.conv2d.weight
# Tracking Gradient For: block8.conv2d.bias
# Tracking Gradient For: last_linear.weight
# Tracking Gradient For: last_bn.weight
# Tracking Gradient For: last_bn.bias
# Tracking Gradient For: logits.weight
# Tracking Gradient For: logits.bias
# Train
# Valid
# tensor(0.1640)
# tensor(0.1577)
# {'acc': tensor(0.9605)}
# Tracking Gradient For: repeat_3.2.branch1.2.bn.bias
# Tracking Gradient For: repeat_3.2.conv2d.weight
# Tracking Gradient For: repeat_3.2.conv2d.bias
# Tracking Gradient For: repeat_3.3.branch0.conv.weight
# Tracking Gradient For: repeat_3.3.branch0.bn.weight
# Tracking Gradient For: repeat_3.3.branch0.bn.bias
# Tracking Gradient For: repeat_3.3.branch1.0.conv.weight
# Tracking Gradient For: repeat_3.3.branch1.0.bn.weight
# Tracking Gradient For: repeat_3.3.branch1.0.bn.bias
# Tracking Gradient For: repeat_3.3.branch1.1.conv.weight
# Tracking Gradient For: repeat_3.3.branch1.1.bn.weight
# Tracking Gradient For: repeat_3.3.branch1.1.bn.bias
# Tracking Gradient For: repeat_3.3.branch1.2.conv.weight
# Tracking Gradient For: repeat_3.3.branch1.2.bn.weight
# Tracking Gradient For: repeat_3.3.branch1.2.bn.bias
# Tracking Gradient For: repeat_3.3.conv2d.weight
# Tracking Gradient For: repeat_3.3.conv2d.bias
# Tracking Gradient For: repeat_3.4.branch0.conv.weight
# Tracking Gradient For: repeat_3.4.branch0.bn.weight
# Tracking Gradient For: repeat_3.4.branch0.bn.bias
# Tracking Gradient For: repeat_3.4.branch1.0.conv.weight
# Tracking Gradient For: repeat_3.4.branch1.0.bn.weight
# Tracking Gradient For: repeat_3.4.branch1.0.bn.bias
# Tracking Gradient For: repeat_3.4.branch1.1.conv.weight
# Tracking Gradient For: repeat_3.4.branch1.1.bn.weight
# Tracking Gradient For: repeat_3.4.branch1.1.bn.bias
# Tracking Gradient For: repeat_3.4.branch1.2.conv.weight
# Tracking Gradient For: repeat_3.4.branch1.2.bn.weight
# Tracking Gradient For: repeat_3.4.branch1.2.bn.bias
# Tracking Gradient For: repeat_3.4.conv2d.weight
# Tracking Gradient For: repeat_3.4.conv2d.bias
# Tracking Gradient For: block8.branch0.conv.weight
# Tracking Gradient For: block8.branch0.bn.weight
# Tracking Gradient For: block8.branch0.bn.bias
# Tracking Gradient For: block8.branch1.0.conv.weight
# Tracking Gradient For: block8.branch1.0.bn.weight
# Tracking Gradient For: block8.branch1.0.bn.bias
# Tracking Gradient For: block8.branch1.1.conv.weight
# Tracking Gradient For: block8.branch1.1.bn.weight
# Tracking Gradient For: block8.branch1.1.bn.bias
# Tracking Gradient For: block8.branch1.2.conv.weight
# Tracking Gradient For: block8.branch1.2.bn.weight
# Tracking Gradient For: block8.branch1.2.bn.bias
# Tracking Gradient For: block8.conv2d.weight
# Tracking Gradient For: block8.conv2d.bias
# Tracking Gradient For: last_linear.weight
# Tracking Gradient For: last_bn.weight
# Tracking Gradient For: last_bn.bias
# Tracking Gradient For: logits.weight
# Tracking Gradient For: logits.bias
# Train
# Valid
# tensor(0.1536)
# tensor(0.1577)
# {'acc': tensor(0.9605)}
# hello
# Tracking Gradient For: repeat_3.2.branch1.1.bn.bias
# Tracking Gradient For: repeat_3.2.branch1.2.conv.weight
# Tracking Gradient For: repeat_3.2.branch1.2.bn.weight
# Tracking Gradient For: repeat_3.2.branch1.2.bn.bias
# Tracking Gradient For: repeat_3.2.conv2d.weight
# Tracking Gradient For: repeat_3.2.conv2d.bias
# Tracking Gradient For: repeat_3.3.branch0.conv.weight
# Tracking Gradient For: repeat_3.3.branch0.bn.weight
# Tracking Gradient For: repeat_3.3.branch0.bn.bias
# Tracking Gradient For: repeat_3.3.branch1.0.conv.weight
# Tracking Gradient For: repeat_3.3.branch1.0.bn.weight
# Tracking Gradient For: repeat_3.3.branch1.0.bn.bias
# Tracking Gradient For: repeat_3.3.branch1.1.conv.weight
# Tracking Gradient For: repeat_3.3.branch1.1.bn.weight
# Tracking Gradient For: repeat_3.3.branch1.1.bn.bias
# Tracking Gradient For: repeat_3.3.branch1.2.conv.weight
# Tracking Gradient For: repeat_3.3.branch1.2.bn.weight
# Tracking Gradient For: repeat_3.3.branch1.2.bn.bias
# Tracking Gradient For: repeat_3.3.conv2d.weight
# Tracking Gradient For: repeat_3.3.conv2d.bias
# Tracking Gradient For: repeat_3.4.branch0.conv.weight
# Tracking Gradient For: repeat_3.4.branch0.bn.weight
# Tracking Gradient For: repeat_3.4.branch0.bn.bias
# Tracking Gradient For: repeat_3.4.branch1.0.conv.weight
# Tracking Gradient For: repeat_3.4.branch1.0.bn.weight
# Tracking Gradient For: repeat_3.4.branch1.0.bn.bias
# Tracking Gradient For: repeat_3.4.branch1.1.conv.weight
# Tracking Gradient For: repeat_3.4.branch1.1.bn.weight
# Tracking Gradient For: repeat_3.4.branch1.1.bn.bias
# Tracking Gradient For: repeat_3.4.branch1.2.conv.weight
# Tracking Gradient For: repeat_3.4.branch1.2.bn.weight
# Tracking Gradient For: repeat_3.4.branch1.2.bn.bias
# Tracking Gradient For: repeat_3.4.conv2d.weight
# Tracking Gradient For: repeat_3.4.conv2d.bias
# Tracking Gradient For: block8.branch0.conv.weight
# Tracking Gradient For: block8.branch0.bn.weight
# Tracking Gradient For: block8.branch0.bn.bias
# Tracking Gradient For: block8.branch1.0.conv.weight
# Tracking Gradient For: block8.branch1.0.bn.weight
# Tracking Gradient For: block8.branch1.0.bn.bias
# Tracking Gradient For: block8.branch1.1.conv.weight
# Tracking Gradient For: block8.branch1.1.bn.weight
# Tracking Gradient For: block8.branch1.1.bn.bias
# Tracking Gradient For: block8.branch1.2.conv.weight
# Tracking Gradient For: block8.branch1.2.bn.weight
# Tracking Gradient For: block8.branch1.2.bn.bias
# Tracking Gradient For: block8.conv2d.weight
# Tracking Gradient For: block8.conv2d.bias
# Tracking Gradient For: last_linear.weight
# Tracking Gradient For: last_bn.weight
# Tracking Gradient For: last_bn.bias
# Tracking Gradient For: logits.weight
# Tracking Gradient For: logits.bias
# Train
# Valid
# tensor(0.1652)
# tensor(0.1536)
# {'acc': tensor(0.9605)}
# Tracking Gradient For: repeat_3.2.branch1.0.bn.bias
# Tracking Gradient For: repeat_3.2.branch1.1.conv.weight
# Tracking Gradient For: repeat_3.2.branch1.1.bn.weight
# Tracking Gradient For: repeat_3.2.branch1.1.bn.bias
# Tracking Gradient For: repeat_3.2.branch1.2.conv.weight
# Tracking Gradient For: repeat_3.2.branch1.2.bn.weight
# Tracking Gradient For: repeat_3.2.branch1.2.bn.bias
# Tracking Gradient For: repeat_3.2.conv2d.weight
# Tracking Gradient For: repeat_3.2.conv2d.bias
# Tracking Gradient For: repeat_3.3.branch0.conv.weight
# Tracking Gradient For: repeat_3.3.branch0.bn.weight
# Tracking Gradient For: repeat_3.3.branch0.bn.bias
# Tracking Gradient For: repeat_3.3.branch1.0.conv.weight
# Tracking Gradient For: repeat_3.3.branch1.0.bn.weight
# Tracking Gradient For: repeat_3.3.branch1.0.bn.bias
# Tracking Gradient For: repeat_3.3.branch1.1.conv.weight
# Tracking Gradient For: repeat_3.3.branch1.1.bn.weight
# Tracking Gradient For: repeat_3.3.branch1.1.bn.bias
# Tracking Gradient For: repeat_3.3.branch1.2.conv.weight
# Tracking Gradient For: repeat_3.3.branch1.2.bn.weight
# Tracking Gradient For: repeat_3.3.branch1.2.bn.bias
# Tracking Gradient For: repeat_3.3.conv2d.weight
# Tracking Gradient For: repeat_3.3.conv2d.bias
# Tracking Gradient For: repeat_3.4.branch0.conv.weight
# Tracking Gradient For: repeat_3.4.branch0.bn.weight
# Tracking Gradient For: repeat_3.4.branch0.bn.bias
# Tracking Gradient For: repeat_3.4.branch1.0.conv.weight
# Tracking Gradient For: repeat_3.4.branch1.0.bn.weight
# Tracking Gradient For: repeat_3.4.branch1.0.bn.bias
# Tracking Gradient For: repeat_3.4.branch1.1.conv.weight
# Tracking Gradient For: repeat_3.4.branch1.1.bn.weight
# Tracking Gradient For: repeat_3.4.branch1.1.bn.bias
# Tracking Gradient For: repeat_3.4.branch1.2.conv.weight
# Tracking Gradient For: repeat_3.4.branch1.2.bn.weight
# Tracking Gradient For: repeat_3.4.branch1.2.bn.bias
# Tracking Gradient For: repeat_3.4.conv2d.weight
# Tracking Gradient For: repeat_3.4.conv2d.bias
# Tracking Gradient For: block8.branch0.conv.weight
# Tracking Gradient For: block8.branch0.bn.weight
# Tracking Gradient For: block8.branch0.bn.bias
# Tracking Gradient For: block8.branch1.0.conv.weight
# Tracking Gradient For: block8.branch1.0.bn.weight
# Tracking Gradient For: block8.branch1.0.bn.bias
# Tracking Gradient For: block8.branch1.1.conv.weight
# Tracking Gradient For: block8.branch1.1.bn.weight
# Tracking Gradient For: block8.branch1.1.bn.bias
# Tracking Gradient For: block8.branch1.2.conv.weight
# Tracking Gradient For: block8.branch1.2.bn.weight
# Tracking Gradient For: block8.branch1.2.bn.bias
# Tracking Gradient For: block8.conv2d.weight
# Tracking Gradient For: block8.conv2d.bias
# Tracking Gradient For: last_linear.weight
# Tracking Gradient For: last_bn.weight
# Tracking Gradient For: last_bn.bias
# Tracking Gradient For: logits.weight
# Tracking Gradient For: logits.bias
# Train
# Valid
# tensor(0.1604)
# tensor(0.1536)
# {'acc': tensor(0.9605)}
# Tracking Gradient For: repeat_3.2.branch0.bn.bias
# Tracking Gradient For: repeat_3.2.branch1.0.conv.weight
# Tracking Gradient For: repeat_3.2.branch1.0.bn.weight
# Tracking Gradient For: repeat_3.2.branch1.0.bn.bias
# Tracking Gradient For: repeat_3.2.branch1.1.conv.weight
# Tracking Gradient For: repeat_3.2.branch1.1.bn.weight
# Tracking Gradient For: repeat_3.2.branch1.1.bn.bias
# Tracking Gradient For: repeat_3.2.branch1.2.conv.weight
# Tracking Gradient For: repeat_3.2.branch1.2.bn.weight
# Tracking Gradient For: repeat_3.2.branch1.2.bn.bias
# Tracking Gradient For: repeat_3.2.conv2d.weight
# Tracking Gradient For: repeat_3.2.conv2d.bias
# Tracking Gradient For: repeat_3.3.branch0.conv.weight
# Tracking Gradient For: repeat_3.3.branch0.bn.weight
# Tracking Gradient For: repeat_3.3.branch0.bn.bias
# Tracking Gradient For: repeat_3.3.branch1.0.conv.weight
# Tracking Gradient For: repeat_3.3.branch1.0.bn.weight
# Tracking Gradient For: repeat_3.3.branch1.0.bn.bias
# Tracking Gradient For: repeat_3.3.branch1.1.conv.weight
# Tracking Gradient For: repeat_3.3.branch1.1.bn.weight
# Tracking Gradient For: repeat_3.3.branch1.1.bn.bias
# Tracking Gradient For: repeat_3.3.branch1.2.conv.weight
# Tracking Gradient For: repeat_3.3.branch1.2.bn.weight
# Tracking Gradient For: repeat_3.3.branch1.2.bn.bias
# Tracking Gradient For: repeat_3.3.conv2d.weight
# Tracking Gradient For: repeat_3.3.conv2d.bias
# Tracking Gradient For: repeat_3.4.branch0.conv.weight
# Tracking Gradient For: repeat_3.4.branch0.bn.weight
# Tracking Gradient For: repeat_3.4.branch0.bn.bias
# Tracking Gradient For: repeat_3.4.branch1.0.conv.weight
# Tracking Gradient For: repeat_3.4.branch1.0.bn.weight
# Tracking Gradient For: repeat_3.4.branch1.0.bn.bias
# Tracking Gradient For: repeat_3.4.branch1.1.conv.weight
# Tracking Gradient For: repeat_3.4.branch1.1.bn.weight
# Tracking Gradient For: repeat_3.4.branch1.1.bn.bias
# Tracking Gradient For: repeat_3.4.branch1.2.conv.weight
# Tracking Gradient For: repeat_3.4.branch1.2.bn.weight
# Tracking Gradient For: repeat_3.4.branch1.2.bn.bias
# Tracking Gradient For: repeat_3.4.conv2d.weight
# Tracking Gradient For: repeat_3.4.conv2d.bias
# Tracking Gradient For: block8.branch0.conv.weight
# Tracking Gradient For: block8.branch0.bn.weight
# Tracking Gradient For: block8.branch0.bn.bias
# Tracking Gradient For: block8.branch1.0.conv.weight
# Tracking Gradient For: block8.branch1.0.bn.weight
# Tracking Gradient For: block8.branch1.0.bn.bias
# Tracking Gradient For: block8.branch1.1.conv.weight
# Tracking Gradient For: block8.branch1.1.bn.weight
# Tracking Gradient For: block8.branch1.1.bn.bias
# Tracking Gradient For: block8.branch1.2.conv.weight
# Tracking Gradient For: block8.branch1.2.bn.weight
# Tracking Gradient For: block8.branch1.2.bn.bias
# Tracking Gradient For: block8.conv2d.weight
# Tracking Gradient For: block8.conv2d.bias
# Tracking Gradient For: last_linear.weight
# Tracking Gradient For: last_bn.weight
# Tracking Gradient For: last_bn.bias
# Tracking Gradient For: logits.weight
# Tracking Gradient For: logits.bias
# Train
# Valid
# tensor(0.1746)
# tensor(0.1536)
# {'acc': tensor(0.9526)}
# Tracking Gradient For: repeat_3.1.conv2d.bias
# Tracking Gradient For: repeat_3.2.branch0.conv.weight
# Tracking Gradient For: repeat_3.2.branch0.bn.weight
# Tracking Gradient For: repeat_3.2.branch0.bn.bias
# Tracking Gradient For: repeat_3.2.branch1.0.conv.weight
# Tracking Gradient For: repeat_3.2.branch1.0.bn.weight
# Tracking Gradient For: repeat_3.2.branch1.0.bn.bias
# Tracking Gradient For: repeat_3.2.branch1.1.conv.weight
# Tracking Gradient For: repeat_3.2.branch1.1.bn.weight
# Tracking Gradient For: repeat_3.2.branch1.1.bn.bias
# Tracking Gradient For: repeat_3.2.branch1.2.conv.weight
# Tracking Gradient For: repeat_3.2.branch1.2.bn.weight
# Tracking Gradient For: repeat_3.2.branch1.2.bn.bias
# Tracking Gradient For: repeat_3.2.conv2d.weight
# Tracking Gradient For: repeat_3.2.conv2d.bias
# Tracking Gradient For: repeat_3.3.branch0.conv.weight
# Tracking Gradient For: repeat_3.3.branch0.bn.weight
# Tracking Gradient For: repeat_3.3.branch0.bn.bias
# Tracking Gradient For: repeat_3.3.branch1.0.conv.weight
# Tracking Gradient For: repeat_3.3.branch1.0.bn.weight
# Tracking Gradient For: repeat_3.3.branch1.0.bn.bias
# Tracking Gradient For: repeat_3.3.branch1.1.conv.weight
# Tracking Gradient For: repeat_3.3.branch1.1.bn.weight
# Tracking Gradient For: repeat_3.3.branch1.1.bn.bias
# Tracking Gradient For: repeat_3.3.branch1.2.conv.weight
# Tracking Gradient For: repeat_3.3.branch1.2.bn.weight
# Tracking Gradient For: repeat_3.3.branch1.2.bn.bias
# Tracking Gradient For: repeat_3.3.conv2d.weight
# Tracking Gradient For: repeat_3.3.conv2d.bias
# Tracking Gradient For: repeat_3.4.branch0.conv.weight
# Tracking Gradient For: repeat_3.4.branch0.bn.weight
# Tracking Gradient For: repeat_3.4.branch0.bn.bias
# Tracking Gradient For: repeat_3.4.branch1.0.conv.weight
# Tracking Gradient For: repeat_3.4.branch1.0.bn.weight
# Tracking Gradient For: repeat_3.4.branch1.0.bn.bias
# Tracking Gradient For: repeat_3.4.branch1.1.conv.weight
# Tracking Gradient For: repeat_3.4.branch1.1.bn.weight
# Tracking Gradient For: repeat_3.4.branch1.1.bn.bias
# Tracking Gradient For: repeat_3.4.branch1.2.conv.weight
# Tracking Gradient For: repeat_3.4.branch1.2.bn.weight
# Tracking Gradient For: repeat_3.4.branch1.2.bn.bias
# Tracking Gradient For: repeat_3.4.conv2d.weight
# Tracking Gradient For: repeat_3.4.conv2d.bias
# Tracking Gradient For: block8.branch0.conv.weight
# Tracking Gradient For: block8.branch0.bn.weight
# Tracking Gradient For: block8.branch0.bn.bias
# Tracking Gradient For: block8.branch1.0.conv.weight
# Tracking Gradient For: block8.branch1.0.bn.weight
# Tracking Gradient For: block8.branch1.0.bn.bias
# Tracking Gradient For: block8.branch1.1.conv.weight
# Tracking Gradient For: block8.branch1.1.bn.weight
# Tracking Gradient For: block8.branch1.1.bn.bias
# Tracking Gradient For: block8.branch1.2.conv.weight
# Tracking Gradient For: block8.branch1.2.bn.weight
# Tracking Gradient For: block8.branch1.2.bn.bias
# Tracking Gradient For: block8.conv2d.weight
# Tracking Gradient For: block8.conv2d.bias
# Tracking Gradient For: last_linear.weight
# Tracking Gradient For: last_bn.weight
# Tracking Gradient For: last_bn.bias
# Tracking Gradient For: logits.weight
# Tracking Gradient For: logits.bias
# Train
# Valid
# tensor(0.1622)
# tensor(0.1536)
# {'acc': tensor(0.9553)}
# Tracking Gradient For: repeat_3.1.branch1.2.bn.weight
# Tracking Gradient For: repeat_3.1.branch1.2.bn.bias
# Tracking Gradient For: repeat_3.1.conv2d.weight
# Tracking Gradient For: repeat_3.1.conv2d.bias
# Tracking Gradient For: repeat_3.2.branch0.conv.weight
# Tracking Gradient For: repeat_3.2.branch0.bn.weight
# Tracking Gradient For: repeat_3.2.branch0.bn.bias
# Tracking Gradient For: repeat_3.2.branch1.0.conv.weight
# Tracking Gradient For: repeat_3.2.branch1.0.bn.weight
# Tracking Gradient For: repeat_3.2.branch1.0.bn.bias
# Tracking Gradient For: repeat_3.2.branch1.1.conv.weight
# Tracking Gradient For: repeat_3.2.branch1.1.bn.weight
# Tracking Gradient For: repeat_3.2.branch1.1.bn.bias
# Tracking Gradient For: repeat_3.2.branch1.2.conv.weight
# Tracking Gradient For: repeat_3.2.branch1.2.bn.weight
# Tracking Gradient For: repeat_3.2.branch1.2.bn.bias
# Tracking Gradient For: repeat_3.2.conv2d.weight
# Tracking Gradient For: repeat_3.2.conv2d.bias
# Tracking Gradient For: repeat_3.3.branch0.conv.weight
# Tracking Gradient For: repeat_3.3.branch0.bn.weight
# Tracking Gradient For: repeat_3.3.branch0.bn.bias
# Tracking Gradient For: repeat_3.3.branch1.0.conv.weight
# Tracking Gradient For: repeat_3.3.branch1.0.bn.weight
# Tracking Gradient For: repeat_3.3.branch1.0.bn.bias
# Tracking Gradient For: repeat_3.3.branch1.1.conv.weight
# Tracking Gradient For: repeat_3.3.branch1.1.bn.weight
# Tracking Gradient For: repeat_3.3.branch1.1.bn.bias
# Tracking Gradient For: repeat_3.3.branch1.2.conv.weight
# Tracking Gradient For: repeat_3.3.branch1.2.bn.weight
# Tracking Gradient For: repeat_3.3.branch1.2.bn.bias
# Tracking Gradient For: repeat_3.3.conv2d.weight
# Tracking Gradient For: repeat_3.3.conv2d.bias
# Tracking Gradient For: repeat_3.4.branch0.conv.weight
# Tracking Gradient For: repeat_3.4.branch0.bn.weight
# Tracking Gradient For: repeat_3.4.branch0.bn.bias
# Tracking Gradient For: repeat_3.4.branch1.0.conv.weight
# Tracking Gradient For: repeat_3.4.branch1.0.bn.weight
# Tracking Gradient For: repeat_3.4.branch1.0.bn.bias
# Tracking Gradient For: repeat_3.4.branch1.1.conv.weight
# Tracking Gradient For: repeat_3.4.branch1.1.bn.weight
# Tracking Gradient For: repeat_3.4.branch1.1.bn.bias
# Tracking Gradient For: repeat_3.4.branch1.2.conv.weight
# Tracking Gradient For: repeat_3.4.branch1.2.bn.weight
# Tracking Gradient For: repeat_3.4.branch1.2.bn.bias
# Tracking Gradient For: repeat_3.4.conv2d.weight
# Tracking Gradient For: repeat_3.4.conv2d.bias
# Tracking Gradient For: block8.branch0.conv.weight
# Tracking Gradient For: block8.branch0.bn.weight
# Tracking Gradient For: block8.branch0.bn.bias
# Tracking Gradient For: block8.branch1.0.conv.weight
# Tracking Gradient For: block8.branch1.0.bn.weight
# Tracking Gradient For: block8.branch1.0.bn.bias
# Tracking Gradient For: block8.branch1.1.conv.weight
# Tracking Gradient For: block8.branch1.1.bn.weight
# Tracking Gradient For: block8.branch1.1.bn.bias
# Tracking Gradient For: block8.branch1.2.conv.weight
# Tracking Gradient For: block8.branch1.2.bn.weight
# Tracking Gradient For: block8.branch1.2.bn.bias
# Tracking Gradient For: block8.conv2d.weight
# Tracking Gradient For: block8.conv2d.bias
# Tracking Gradient For: last_linear.weight
# Tracking Gradient For: last_bn.weight
# Tracking Gradient For: last_bn.bias
# Tracking Gradient For: logits.weight
# Tracking Gradient For: logits.bias
# Train
# Valid
# tensor(0.1697)
# tensor(0.1536)
# {'acc': tensor(0.9553)}
# No Improvement for 5 epochs, Early Stopping
